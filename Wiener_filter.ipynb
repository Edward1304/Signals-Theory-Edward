# %% [markdown]
# <a href="https://colab.research.google.com/github/Edward1304/Signals-Theory-Edward/blob/main/Wiener_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt  # data plotting
from matplotlib.pyplot import figure
from matplotlib import rcParams

rcParams['figure.figsize']     = [15,6]
rcParams['lines.markersize']   = 6         # marker size in points
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['axes.titlesize'] = 9
plt.rcParams['figure.dpi']     = 120

# %%
Nsample = 100

np.random.seed(0)
t = np.linspace(0, 5, Nsample)
x = np.sin(t) + .1 * np.random.normal(size=Nsample)

# %%
from scipy import signal

plt.figure()
plt.plot(x, label='Original signal')
plt.plot(signal.medfilt(x), label='medfilt: median filter')
plt.plot(signal.wiener(x), label='wiener: wiener filter')
plt.xlim(0,Nsample-1)
plt.legend(loc='best')
plt.show()
